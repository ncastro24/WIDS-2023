# %%
# data libraries
import numpy as np
import pandas as pd

# plotting libraries
import matplotlib.pyplot as plt
import seaborn as sns
from plotnine import *

# notebook display settings
pd.options.display.max_columns = 500
pd.options.display.max_rows = 500

# warning settings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Questions:
#
# How many variables do we have? **246**
#
# How many categorical?
#
# How many continuous?
#
# What variables do you think will be important?
#
# What variables do you not understand and need to look up?
#
# What are we predicting and how will model success be measured?
#
# We are predicting **contest-tmp2m-14d__tmp2m**
#
# Can a simple model like linear regression work? Try that first!

# %%
#Load data

trainData = pd.read_csv('train_data.csv')
testData = pd.read_csv('test_data.csv')

trainData.head()
# Out:
#    index  lat       lon startdate  contest-pevpr-sfc-gauss-14d__pevpr  \
# 0      0  0.0  0.833333    9/1/14                              237.00
# 1      1  0.0  0.833333    9/2/14                              228.90
# 2      2  0.0  0.833333    9/3/14                              220.69
# 3      3  0.0  0.833333    9/4/14                              225.28
# 4      4  0.0  0.833333    9/5/14                              237.24
#
#    nmme0-tmp2m-34w__cancm30  nmme0-tmp2m-34w__cancm40  \
# 0                     29.02                     31.64
# 1                     29.02                     31.64
# 2                     29.02                     31.64
# 3                     29.02                     31.64
# 4                     29.02                     31.64
#
#    nmme0-tmp2m-34w__ccsm30  nmme0-tmp2m-34w__ccsm40  nmme0-tmp2m-34w__cfsv20  \
# 0                    29.57                    30.73                    29.71
# ...

# %%
#How many variables do we have?

trainData.shape
# Out:
# (32690, 246)

# %%
#Cleaning Data

#Check how many missing values there are and where they occur
trainData.isnull().sum()
# Out:
# index                                          0
# lat                                            0
# lon                                            0
# startdate                                      0
# contest-pevpr-sfc-gauss-14d__pevpr             0
# nmme0-tmp2m-34w__cancm30                       0
# nmme0-tmp2m-34w__cancm40                       0
# nmme0-tmp2m-34w__ccsm30                     5053
# nmme0-tmp2m-34w__ccsm40                        0
# nmme0-tmp2m-34w__cfsv20                        0
# nmme0-tmp2m-34w__gfdlflora0                    0
# nmme0-tmp2m-34w__gfdlflorb0                    0
# nmme0-tmp2m-34w__gfdl0                         0
# nmme0-tmp2m-34w__nasa0                         0
# nmme0-tmp2m-34w__nmme0mean                     0
# contest-wind-h10-14d__wind-hgt-10              0
# nmme-tmp2m-56w__cancm3                         0
# nmme-tmp2m-56w__cancm4                         0
# nmme-tmp2m-56w__ccsm3                       3260
# ...

# %%
#Remove Duplicates
df_dropped = trainData.drop_duplicates()

# %%
#Scaling/Standardizing
from sklearn.preprocessing import StandardScaler, MinMaxScaler

df_scale = df_dropped.copy()

# z score
z = StandardScaler()
df_scale = z.fit_transform(df_scale)

print(df_scale.head())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-d08cc9954b18> in <module>
#       6 # z score
#       7 z = StandardScaler()
# ----> 8 df_scale = z.fit_transform(df_scale)
#       9
#      10 print(df_scale.head())
#
# /usr/local/lib/python3.8/dist-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     850         if y is None:
#     851             # fit method of arity 1 (unsupervised transformation)
# --> 852             return self.fit(X, **fit_params).transform(X)
#     853         else:
#     854             # fit method of arity 2 (supervised transformation)
#
# /usr/local/lib/python3.8/dist-packages/sklearn/preprocessing/_data.py in fit(self, X, y, sample_weight)
#     804         # Reset internal state before fitting
#     805         self._reset()
# --> 806         return self.partial_fit(X, y, sample_weight)
#     807
# ...

# %%
#Make summary tables
#Summary statistics for numeric variables (mean, median, min, max, etc.)
trainData.describe()
# Out:
#               index           lat           lon  \
# count  32690.000000  32690.000000  32690.000000
# mean   16344.500000      0.155106      0.760167
# std     9436.934486      0.063136      0.162978
# min        0.000000      0.000000      0.366667
# 25%     8172.250000      0.136364      0.666667
# 50%    16344.500000      0.181818      0.800000
# 75%    24516.750000      0.227273      0.866667
# max    32689.000000      0.227273      1.000000
#
#        contest-pevpr-sfc-gauss-14d__pevpr  nmme0-tmp2m-34w__cancm30  \
# count                        32690.000000              32690.000000
# mean                           320.020631                 18.967442
# std                            148.527047                  9.096952
# min                             43.330000                  0.630000
# 25%                            206.595000                 10.850000
# 50%                            284.680000                 20.240000
# ...

# %%
#What are the counts for each categorial variable?

# %%
#Split by any important variable (e.g. year, gender, etc.)
trainData.groupby('contest-pevpr-sfc-gauss-14d__pevpr').size()
# Out:
# contest-pevpr-sfc-gauss-14d__pevpr
# 43.33     1
# 44.93     1
# 47.02     1
# 47.11     1
# 47.66     1
#          ..
# 763.81    1
# 765.29    1
# 770.46    1
# 771.25    1
# 772.89    1
# Length: 24011, dtype: int64

# %%
#DATA VISUALIZATION

#Bar charts -> good for counts or means of categorical data (e.g. avg rainfall per month)

#Boxplots -> good for measuring range/distribution of continuous variables

#Histograms -> good for measuring range/distribution of continuous variables (think carefully about bin size!)
#Create histogram for the variable you are predicting

#Scatterplots -> good for showing the relationship between two continuous variables

#Correlation Plots -> Shows the pairwise correlations between all your variables -> good to get a general idea about relationships in the data
#Make a heat map!

# %%
#Missing data
